# %% [markdown]
# # 3주차 스터디 과제
#
# Made by 35기 코딩부장 류제현
#
#     데이터를 불러와 들여다보고, 전처리를 수행해 봅시다

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 문제풀이 하실 때 주석 꼼꼼하게 확인 부탁드립니다

# %% [markdown]
#     1. 우선 사용할 CSV파일 2개를 불러오겠습니다
#
# * 자기주식처분_코스닥 / 자기주식처분_코스피 데이터를 불러옵니다

# %%
# 코드
## Colab는 적절한 경로를 지정해주세요
kosdaq = pd.read_csv("Data/자기주식처분_코스닥_연습문제용.csv", index_col=0)
kospi = pd.read_csv("Data/자기주식처분_코스피_연습문제용.csv", index_col=0)

# %% [markdown]
#     2. 파일 두 개를 하나의 데이터프레임으로 합치고(concat), 공시일을 기준으로 정렬해 봅시다 / 이후 인덱스도 예쁘게 맞춰줍시다

# %%
# 코드
#merge files
df=pd.concat([kospi,kosdaq])
#공시일을 기준으로 정렬
df=df.sort_values(by="공시일").reset_index(drop=True)
df
# Out:
#              공시일   기업공시코드   처분예정금액(보통주식) 처분예정금액(기타주식)          처분시작일  \
# 0     2019-01-02  A039440     16,320,000            -     2019.01.03
# 1     2019-01-08  A095270  4,000,000,000            -  2019년 01월 10일
# 2     2019-01-10  A101330     72,000,000            -     2019.01.10
# 3     2019-01-11  A227950  4,561,934,250            -  2019년 01월 11일
# 4     2019-01-11  A232140     47,880,000            -  2019년 01월 11일
# ...          ...      ...            ...          ...            ...
# 1229  2022-12-28  A234340    376,827,500            -  2022년 12월 28일
# 1230  2022-12-28  A078350  1,252,794,200            -  2022년 12월 29일
# 1231  2022-12-29  A285490  4,922,000,000            -  2022년 12월 30일
# 1232  2022-12-30  A001570  1,912,000,000            -  2022년 12월 30일
# 1233  2022-12-30  A214450  1,122,943,500            -     2023.01.09
#
#               처분종료일                                               처분목적  \
# 0        2023.03.20                             주식매수선택권 행사에 따른 자기주식 교부
# 1     2019년 01월 10일                         자기주식을 교환대상으로 하는 사모 교환사채 발행
# 2        2019.01.18                                           임직원공로금지급
# 3     2019년 01월 18일  합병시 주주의 주식매수청구권 행사로 취득한 자기주식은 5년 이내에 처분해야 하며, ...
# 4     2019년 01월 11일                                        우리사주조합 무상출연
# ...             ...                                                ...
# 1229  2023년 01월 06일                                             임직원 상여
# 1230  2022년 12월 29일                                     임직원에 대한 상여금 지급
# 1231  2022년 12월 30일                                    사내근로복지기금 출연금 출연
# 1232  2022년 12월 30일                              임원 제한조건부 가상주식(RSU) 지급
# 1233     2023.01.30                   2022년 경영성과에 따른 특별성과급 명목의 자기주식 지급
#
#               처분방법
# 0     시장을 통한 매도(주)
# 1     시장을 통한 매도(주)
# 2     시장을 통한 매도(주)
# 3     시장을 통한 매도(주)
# 4     시장을 통한 매도(주)
# ...            ...
# 1229  시장을 통한 매도(주)
# 1230  시장을 통한 매도(주)
# 1231  시장을 통한 매도(주)
# 1232  시장을 통한 매도(주)
# 1233  시장을 통한 매도(주)
#
# [1234 rows x 8 columns]

# %% [markdown]
#     3. 보통주식과 기타주식의 처분예정금액 컬럼이 보입니다. -> 이 컬럼들을 int64타입으로 변경해줍시다
#
#   * 주의) 처분예정금액에 아무 숫자가 없는 데이터("-" 로 표기되어있습니다)는 0으로 바꿔줍시다
#   * 주의2) 숫자 사이에 쉼표가 있으면 변경이 안되겠죠?

# %%
# 코드
df["처분예정금액(보통주식)"]=df["처분예정금액(보통주식)"].astype("string")
df["처분예정금액(기타주식)"]=df["처분예정금액(기타주식)"].astype("string")
df["처분예정금액(보통주식)"]= df["처분예정금액(보통주식)"].str.replace("-","0")
df["처분예정금액(기타주식)"]= df["처분예정금액(기타주식)"].str.replace("-","0")
df["처분예정금액(보통주식)"]= df["처분예정금액(보통주식)"].str.replace(",","")
df["처분예정금액(기타주식)"]=df["처분예정금액(기타주식)"].str.replace(",","")
df["처분예정금액(보통주식)"]=df["처분예정금액(보통주식)"].astype("int64")
df["처분예정금액(기타주식)"]=df["처분예정금액(기타주식)"].astype("int64")
df
# Out:
#              공시일   기업공시코드  처분예정금액(보통주식)  처분예정금액(기타주식)          처분시작일  \
# 0     2019-01-02  A039440      16320000             0     2019.01.03
# 1     2019-01-08  A095270    4000000000             0  2019년 01월 10일
# 2     2019-01-10  A101330      72000000             0     2019.01.10
# 3     2019-01-11  A227950    4561934250             0  2019년 01월 11일
# 4     2019-01-11  A232140      47880000             0  2019년 01월 11일
# ...          ...      ...           ...           ...            ...
# 1229  2022-12-28  A234340     376827500             0  2022년 12월 28일
# 1230  2022-12-28  A078350    1252794200             0  2022년 12월 29일
# 1231  2022-12-29  A285490    4922000000             0  2022년 12월 30일
# 1232  2022-12-30  A001570    1912000000             0  2022년 12월 30일
# 1233  2022-12-30  A214450    1122943500             0     2023.01.09
#
#               처분종료일                                               처분목적  \
# 0        2023.03.20                             주식매수선택권 행사에 따른 자기주식 교부
# 1     2019년 01월 10일                         자기주식을 교환대상으로 하는 사모 교환사채 발행
# 2        2019.01.18                                           임직원공로금지급
# 3     2019년 01월 18일  합병시 주주의 주식매수청구권 행사로 취득한 자기주식은 5년 이내에 처분해야 하며, ...
# 4     2019년 01월 11일                                        우리사주조합 무상출연
# ...             ...                                                ...
# 1229  2023년 01월 06일                                             임직원 상여
# 1230  2022년 12월 29일                                     임직원에 대한 상여금 지급
# 1231  2022년 12월 30일                                    사내근로복지기금 출연금 출연
# 1232  2022년 12월 30일                              임원 제한조건부 가상주식(RSU) 지급
# 1233     2023.01.30                   2022년 경영성과에 따른 특별성과급 명목의 자기주식 지급
#
#               처분방법
# 0     시장을 통한 매도(주)
# 1     시장을 통한 매도(주)
# 2     시장을 통한 매도(주)
# 3     시장을 통한 매도(주)
# 4     시장을 통한 매도(주)
# ...            ...
# 1229  시장을 통한 매도(주)
# 1230  시장을 통한 매도(주)
# 1231  시장을 통한 매도(주)
# 1232  시장을 통한 매도(주)
# 1233  시장을 통한 매도(주)
#
# [1234 rows x 8 columns]

# %% [markdown]
#     4. 처분예정금액(보통주식) 컬럼과 처분예정금액(기타주식) 컬럼을 더해서 "처분예정금액(전체주식)" 컬럼을 데이터프레임에 새로 추가해 봅시다!

# %%
# 코드 
df["처분예정금액(전체주식)"]=df["처분예정금액(보통주식)"]+df["처분예정금액(기타주식)"]
df
# Out:
#              공시일   기업공시코드  처분예정금액(보통주식)  처분예정금액(기타주식)          처분시작일  \
# 0     2019-01-02  A039440      16320000             0     2019.01.03
# 1     2019-01-08  A095270    4000000000             0  2019년 01월 10일
# 2     2019-01-10  A101330      72000000             0     2019.01.10
# 3     2019-01-11  A227950    4561934250             0  2019년 01월 11일
# 4     2019-01-11  A232140      47880000             0  2019년 01월 11일
# ...          ...      ...           ...           ...            ...
# 1229  2022-12-28  A234340     376827500             0  2022년 12월 28일
# 1230  2022-12-28  A078350    1252794200             0  2022년 12월 29일
# 1231  2022-12-29  A285490    4922000000             0  2022년 12월 30일
# 1232  2022-12-30  A001570    1912000000             0  2022년 12월 30일
# 1233  2022-12-30  A214450    1122943500             0     2023.01.09
#
#               처분종료일                                               처분목적  \
# 0        2023.03.20                             주식매수선택권 행사에 따른 자기주식 교부
# 1     2019년 01월 10일                         자기주식을 교환대상으로 하는 사모 교환사채 발행
# 2        2019.01.18                                           임직원공로금지급
# 3     2019년 01월 18일  합병시 주주의 주식매수청구권 행사로 취득한 자기주식은 5년 이내에 처분해야 하며, ...
# 4     2019년 01월 11일                                        우리사주조합 무상출연
# ...             ...                                                ...
# 1229  2023년 01월 06일                                             임직원 상여
# 1230  2022년 12월 29일                                     임직원에 대한 상여금 지급
# 1231  2022년 12월 30일                                    사내근로복지기금 출연금 출연
# 1232  2022년 12월 30일                              임원 제한조건부 가상주식(RSU) 지급
# 1233     2023.01.30                   2022년 경영성과에 따른 특별성과급 명목의 자기주식 지급
#
#               처분방법  처분예정금액(전체주식)
# 0     시장을 통한 매도(주)      16320000
# 1     시장을 통한 매도(주)    4000000000
# 2     시장을 통한 매도(주)      72000000
# 3     시장을 통한 매도(주)    4561934250
# 4     시장을 통한 매도(주)      47880000
# ...            ...           ...
# 1229  시장을 통한 매도(주)     376827500
# 1230  시장을 통한 매도(주)    1252794200
# 1231  시장을 통한 매도(주)    4922000000
# 1232  시장을 통한 매도(주)    1912000000
# 1233  시장을 통한 매도(주)    1122943500
#
# [1234 rows x 9 columns]

# %% [markdown]
#     5. 한 번에 가장 많은 금액의 주식을 처분한 기업의 기업공시코드는 무엇인가요? (처분예정금액(전체주식) 컬럼 사용)
#     그리고 이 회사의 이름은 뭘까요?(-> 네이버에 기업공시코드를 검색해봅시다)
#
# * argmax 또는 idxmax를 사용할 수 있습니다 -> 또 다른 방법이 있다면 저에게도 알려주세요!!

# %%
# 코드
df['처분예정금액(전체주식)'].argmax()
df.loc[761,"기업공시코드"]    #기업의 이름은 POSCO홀딩스입니다!!
# Out:
# 'A005490'

# %%
df
# Out:
#              공시일   기업공시코드  처분예정금액(보통주식)  처분예정금액(기타주식)          처분시작일  \
# 0     2019-01-02  A039440      16320000             0     2019.01.03
# 1     2019-01-08  A095270    4000000000             0  2019년 01월 10일
# 2     2019-01-10  A101330      72000000             0     2019.01.10
# 3     2019-01-11  A227950    4561934250             0  2019년 01월 11일
# 4     2019-01-11  A232140      47880000             0  2019년 01월 11일
# ...          ...      ...           ...           ...            ...
# 1229  2022-12-28  A234340     376827500             0  2022년 12월 28일
# 1230  2022-12-28  A078350    1252794200             0  2022년 12월 29일
# 1231  2022-12-29  A285490    4922000000             0  2022년 12월 30일
# 1232  2022-12-30  A001570    1912000000             0  2022년 12월 30일
# 1233  2022-12-30  A214450    1122943500             0     2023.01.09
#
#               처분종료일                                               처분목적  \
# 0        2023.03.20                             주식매수선택권 행사에 따른 자기주식 교부
# 1     2019년 01월 10일                         자기주식을 교환대상으로 하는 사모 교환사채 발행
# 2        2019.01.18                                           임직원공로금지급
# 3     2019년 01월 18일  합병시 주주의 주식매수청구권 행사로 취득한 자기주식은 5년 이내에 처분해야 하며, ...
# 4     2019년 01월 11일                                        우리사주조합 무상출연
# ...             ...                                                ...
# 1229  2023년 01월 06일                                             임직원 상여
# 1230  2022년 12월 29일                                     임직원에 대한 상여금 지급
# 1231  2022년 12월 30일                                    사내근로복지기금 출연금 출연
# 1232  2022년 12월 30일                              임원 제한조건부 가상주식(RSU) 지급
# 1233     2023.01.30                   2022년 경영성과에 따른 특별성과급 명목의 자기주식 지급
#
#               처분방법  처분예정금액(전체주식)
# 0     시장을 통한 매도(주)      16320000
# 1     시장을 통한 매도(주)    4000000000
# 2     시장을 통한 매도(주)      72000000
# 3     시장을 통한 매도(주)    4561934250
# 4     시장을 통한 매도(주)      47880000
# ...            ...           ...
# 1229  시장을 통한 매도(주)     376827500
# 1230  시장을 통한 매도(주)    1252794200
# 1231  시장을 통한 매도(주)    4922000000
# 1232  시장을 통한 매도(주)    1912000000
# 1233  시장을 통한 매도(주)    1122943500
#
# [1234 rows x 9 columns]

# %% [markdown]
#     6. 처분시작일부터 처분종료일까지 가장 오랜 시간을 계획한 기업의 기업공시코드는 무엇인가요?
#     그리고 이 회사의 이름은 뭘까요?
#
# * pd.to_datetime으로 데이터를 변환하면, 날짜 연산이 가능해집니다
#
# * 중요!!) 년/월/일 꼴로 "한글"이 기록되어 있는 경우가 있는데 이를 전부 변환해줘야합니다!! (Ex. 20190101 꼴로 replace 함수를 사용해 변경해줍니다)
#
# * 중요!!) replace함수로 "." 을 제거할 때는 반드시 *replace(".","", regex=False)* 로 설정해 줘야 합니다!!

# %%
# 코드6-1 -> 우선 날짜형태를 변환해 봅시다 
## 예시 (2020년 01월 01일 or 2020.01.01) 형태를 -> 20200101 형태로 변형해줘야 합니다!!
## replace를 사용합니다 (아직 datetime으로 바꾸지는 말아주세요)
df["처분종료일"]=df["처분종료일"].astype("string")
df["처분시작일"]=df["처분시작일"].astype("string")

df["처분시작일"] = df["처분시작일"].str.replace("년","")
df["처분시작일"] = df["처분시작일"].str.replace("월","")
df["처분시작일"] = df["처분시작일"].str.replace("일","")
df["처분시작일"] = df["처분시작일"].str.replace(".","",regex=False)
df["처분시작일"] = df["처분시작일"].str.replace(" ","")
df["처분시작일"] = df["처분시작일"].str.replace("-","")


df["처분종료일"] = df["처분종료일"].str.replace("년","")
df["처분종료일"] = df["처분종료일"].str.replace("월","")
df["처분종료일"] = df["처분종료일"].str.replace("일","")
df["처분종료일"] = df["처분종료일"].str.replace(".","",regex=False)
df["처분종료일"] = df["처분종료일"].str.replace(" ","")
df["처분종료일"] = df["처분종료일"].str.replace("-","")
df
# Out:
#              공시일   기업공시코드  처분예정금액(보통주식)  처분예정금액(기타주식)     처분시작일     처분종료일  \
# 0     2019-01-02  A039440      16320000             0  20190103  20230320
# 1     2019-01-08  A095270    4000000000             0  20190110  20190110
# 2     2019-01-10  A101330      72000000             0  20190110  20190118
# 3     2019-01-11  A227950    4561934250             0  20190111  20190118
# 4     2019-01-11  A232140      47880000             0  20190111  20190111
# ...          ...      ...           ...           ...       ...       ...
# 1229  2022-12-28  A234340     376827500             0  20221228  20230106
# 1230  2022-12-28  A078350    1252794200             0  20221229  20221229
# 1231  2022-12-29  A285490    4922000000             0  20221230  20221230
# 1232  2022-12-30  A001570    1912000000             0  20221230  20221230
# 1233  2022-12-30  A214450    1122943500             0  20230109  20230130
#
#                                                    처분목적          처분방법  \
# 0                                주식매수선택권 행사에 따른 자기주식 교부  시장을 통한 매도(주)
# 1                            자기주식을 교환대상으로 하는 사모 교환사채 발행  시장을 통한 매도(주)
# 2                                              임직원공로금지급  시장을 통한 매도(주)
# 3     합병시 주주의 주식매수청구권 행사로 취득한 자기주식은 5년 이내에 처분해야 하며, ...  시장을 통한 매도(주)
# 4                                           우리사주조합 무상출연  시장을 통한 매도(주)
# ...                                                 ...           ...
# 1229                                             임직원 상여  시장을 통한 매도(주)
# 1230                                     임직원에 대한 상여금 지급  시장을 통한 매도(주)
# 1231                                    사내근로복지기금 출연금 출연  시장을 통한 매도(주)
# 1232                              임원 제한조건부 가상주식(RSU) 지급  시장을 통한 매도(주)
# 1233                   2022년 경영성과에 따른 특별성과급 명목의 자기주식 지급  시장을 통한 매도(주)
#
#       처분예정금액(전체주식)
# 0         16320000
# 1       4000000000
# 2         72000000
# 3       4561934250
# 4         47880000
# ...            ...
# 1229     376827500
# 1230    1252794200
# 1231    4922000000
# 1232    1912000000
# 1233    1122943500
#
# [1234 rows x 9 columns]

# %%
# 코드6-2 -> 대충 봤을 때는 처분시작일과 처분종료일 데이터가 완전해 보이지만 그렇지 않을 수도 있죠? 
## 처분종료일을 int64 데이터타입으로 변경해서 변경이 잘 되는지 한 번 확인해 봅시다
df.loc[df["처분종료일"]=='']
# Out:
#              공시일   기업공시코드  처분예정금액(보통주식)  처분예정금액(기타주식)     처분시작일 처분종료일  \
# 236   2020-02-05  A003070     603927850             0  20200206
# 446   2020-11-18  A065150    4992000000             0
# 483   2020-12-17  A134380     344811500             0  20201218
# 872   2021-12-16  A134380     346808000             0  20211217
# 1208  2022-12-15  A134380     312083200             0  20221216
#
#             처분목적          처분방법  처분예정금액(전체주식)
# 236   임직원 격려금 지급  시장을 통한 매도(주)     603927850
# 446      운영자금 확보  시장을 통한 매도(주)    4992000000
# 483   우리사주조합에 매각  시장을 통한 매도(주)     344811500
# 872   우리사주조합에 매각  시장을 통한 매도(주)     346808000
# 1208  우리사주조합에 매각  시장을 통한 매도(주)     312083200

# %%
df.loc[df["처분시작일"]=='']
# Out:
#             공시일   기업공시코드  처분예정금액(보통주식)  처분예정금액(기타주식) 처분시작일 처분종료일     처분목적  \
# 446  2020-11-18  A065150    4992000000             0              운영자금 확보
#
#              처분방법  처분예정금액(전체주식)
# 446  시장을 통한 매도(주)    4992000000

# %% [markdown]
# 네.... '-'와 같은 값이 존재해서 오류가 뜨는 것을 확인할 수 있습니다.

# %%
# 코드6-3  처분종료일에 '-'값을 가진 데이터를 제외하고 온전한 날짜가 존재하는 데이터만 추출해봅시다
## Note) 처분시작일은 가만히 놔두고, 처분종료일만 고려합시다!
df.drop([236,446,483,872,1208],axis=0,inplace=True)

# %%
df["처분시작일"]=df["처분시작일"].astype("string")
df["처분종료일"]=df["처분종료일"].astype("string")

# %%
df
# Out:
#              공시일   기업공시코드  처분예정금액(보통주식)  처분예정금액(기타주식)     처분시작일     처분종료일  \
# 0     2019-01-02  A039440      16320000             0  20190103  20230320
# 1     2019-01-08  A095270    4000000000             0  20190110  20190110
# 2     2019-01-10  A101330      72000000             0  20190110  20190118
# 3     2019-01-11  A227950    4561934250             0  20190111  20190118
# 4     2019-01-11  A232140      47880000             0  20190111  20190111
# ...          ...      ...           ...           ...       ...       ...
# 1229  2022-12-28  A234340     376827500             0  20221228  20230106
# 1230  2022-12-28  A078350    1252794200             0  20221229  20221229
# 1231  2022-12-29  A285490    4922000000             0  20221230  20221230
# 1232  2022-12-30  A001570    1912000000             0  20221230  20221230
# 1233  2022-12-30  A214450    1122943500             0  20230109  20230130
#
#                                                    처분목적          처분방법  \
# 0                                주식매수선택권 행사에 따른 자기주식 교부  시장을 통한 매도(주)
# 1                            자기주식을 교환대상으로 하는 사모 교환사채 발행  시장을 통한 매도(주)
# 2                                              임직원공로금지급  시장을 통한 매도(주)
# 3     합병시 주주의 주식매수청구권 행사로 취득한 자기주식은 5년 이내에 처분해야 하며, ...  시장을 통한 매도(주)
# 4                                           우리사주조합 무상출연  시장을 통한 매도(주)
# ...                                                 ...           ...
# 1229                                             임직원 상여  시장을 통한 매도(주)
# 1230                                     임직원에 대한 상여금 지급  시장을 통한 매도(주)
# 1231                                    사내근로복지기금 출연금 출연  시장을 통한 매도(주)
# 1232                              임원 제한조건부 가상주식(RSU) 지급  시장을 통한 매도(주)
# 1233                   2022년 경영성과에 따른 특별성과급 명목의 자기주식 지급  시장을 통한 매도(주)
#
#       처분예정금액(전체주식)
# 0         16320000
# 1       4000000000
# 2         72000000
# 3       4561934250
# 4         47880000
# ...            ...
# 1229     376827500
# 1230    1252794200
# 1231    4922000000
# 1232    1912000000
# 1233    1122943500
#
# [1229 rows x 9 columns]

# %%
# 코드6-4  자 이제 준비가 끝났습니다... 이제 처분종료일과 처분시작일을 판다스의 datetime으로 바꿔주고,
# "처분종료일 - 처분시작일" 연산을 수행해봅시다
df['처분시작일']=pd.to_datetime(df['처분시작일'])
df['처분종료일']=pd.to_datetime(df['처분종료일'])
df['누가오래했나']=df['처분종료일']-df['처분시작일']
df
# Out:
#              공시일   기업공시코드  처분예정금액(보통주식)  처분예정금액(기타주식)      처분시작일      처분종료일  \
# 0     2019-01-02  A039440      16320000             0 2019-01-03 2023-03-20
# 1     2019-01-08  A095270    4000000000             0 2019-01-10 2019-01-10
# 2     2019-01-10  A101330      72000000             0 2019-01-10 2019-01-18
# 3     2019-01-11  A227950    4561934250             0 2019-01-11 2019-01-18
# 4     2019-01-11  A232140      47880000             0 2019-01-11 2019-01-11
# ...          ...      ...           ...           ...        ...        ...
# 1229  2022-12-28  A234340     376827500             0 2022-12-28 2023-01-06
# 1230  2022-12-28  A078350    1252794200             0 2022-12-29 2022-12-29
# 1231  2022-12-29  A285490    4922000000             0 2022-12-30 2022-12-30
# 1232  2022-12-30  A001570    1912000000             0 2022-12-30 2022-12-30
# 1233  2022-12-30  A214450    1122943500             0 2023-01-09 2023-01-30
#
#                                                    처분목적          처분방법  \
# 0                                주식매수선택권 행사에 따른 자기주식 교부  시장을 통한 매도(주)
# 1                            자기주식을 교환대상으로 하는 사모 교환사채 발행  시장을 통한 매도(주)
# 2                                              임직원공로금지급  시장을 통한 매도(주)
# 3     합병시 주주의 주식매수청구권 행사로 취득한 자기주식은 5년 이내에 처분해야 하며, ...  시장을 통한 매도(주)
# 4                                           우리사주조합 무상출연  시장을 통한 매도(주)
# ...                                                 ...           ...
# 1229                                             임직원 상여  시장을 통한 매도(주)
# 1230                                     임직원에 대한 상여금 지급  시장을 통한 매도(주)
# 1231                                    사내근로복지기금 출연금 출연  시장을 통한 매도(주)
# 1232                              임원 제한조건부 가상주식(RSU) 지급  시장을 통한 매도(주)
# 1233                   2022년 경영성과에 따른 특별성과급 명목의 자기주식 지급  시장을 통한 매도(주)
#
#       처분예정금액(전체주식)    누가오래했나
# 0         16320000 1537 days
# 1       4000000000    0 days
# 2         72000000    8 days
# 3       4561934250    7 days
# 4         47880000    0 days
# ...            ...       ...
# 1229     376827500    9 days
# 1230    1252794200    0 days
# 1231    4922000000    0 days
# 1232    1912000000    0 days
# 1233    1122943500   21 days
#
# [1229 rows x 10 columns]

# %%
# 코드 6-5 위에서 연산한 값을 통해 처분에 가장 오랜 시간이 걸린 기업공시코드를 찾아봅시다! 
# 이 회사의 이름은 무엇인가요? 그리고 얼마나 많은 시간이 걸렸나요?
df['누가오래했나'].argmax()
df.loc[619,"기업공시코드"]
# Out:
# 'A032850'

# %% [markdown]
#     7. 우리가 앞서 사용했던 데이터프레임의 기업공시코드에 알맞은 회사명을 한 번 추가해 봅시다!!
#
# * 기업명_기업코드 파일을 불러옵시다 -> 이 파일에는 앞서 봤던 기업공시코드 mapping되는 회사명을 가지고 있습니다 (Dart코드는 무시하셔도 됩니다)

# %%
# 7-1 기업명_기업코드 파일을 불러옵시다
## Colab을 사용하신다면 적절한 경로를 지정해주세요
code_df = pd.read_csv("/기업명_기업코드.csv", index_col=0)
code_df.head()
code_df.drop(['Dart코드'],axis='columns',inplace=True)
code_df
# Out:
#              회사명   기업공시코드
# 0           신한은행  A000010
# 1           동화약품  A000020
# 2           우리은행  A000030
# 3          KR모터스  A000040
# 4             경방  A000050
# ...          ...      ...
# 3528       에스앤케이  A950180
# 3529         미투젠  A950190
# 3530         소마젠  A950200
# 3531  프레스티지바이오파마  A950210
# 3532       네오이뮨텍  A950220
#
# [3533 rows x 2 columns]

# %%
# 7-2 각 기업공시코드에 알맞은 회사명을 추가해 봅시다
## 힌트 pd.merge를 사용하면 됩니다
## 이후, 공시일 순으로 정렬하고, 인덱스를 reset해 줍시다
data=pd.merge(df,code_df,on='기업공시코드',how='right')
data=data.sort_values(by="공시일").reset_index(drop=True)
data
# Out:
#              공시일   기업공시코드  처분예정금액(보통주식)  처분예정금액(기타주식)  \
# 0     2019-01-02  A039440  1.632000e+07           0.0
# 1     2019-01-08  A095270  4.000000e+09           0.0
# 2     2019-01-10  A101330  7.200000e+07           0.0
# 3     2019-01-11  A232140  4.788000e+07           0.0
# 4     2019-01-11  A227950  4.561934e+09           0.0
# ...          ...      ...           ...           ...
# 4163         NaN  A950170           NaN           NaN
# 4164         NaN  A950190           NaN           NaN
# 4165         NaN  A950200           NaN           NaN
# 4166         NaN  A950210           NaN           NaN
# 4167         NaN  A950220           NaN           NaN
#
#                              처분시작일                         처분종료일  \
# 0    1970-01-01 00:00:00.020190103 1970-01-01 00:00:00.020230320
# 1    1970-01-01 00:00:00.020190110 1970-01-01 00:00:00.020190110
# 2    1970-01-01 00:00:00.020190110 1970-01-01 00:00:00.020190118
# 3    1970-01-01 00:00:00.020190111 1970-01-01 00:00:00.020190111
# 4    1970-01-01 00:00:00.020190111 1970-01-01 00:00:00.020190118
# ...                            ...                           ...
# 4163                           NaT                           NaT
# 4164                           NaT                           NaT
# 4165                           NaT                           NaT
# 4166                           NaT                           NaT
# 4167                           NaT                           NaT
#
#                                                    처분목적          처분방법  \
# 0                                주식매수선택권 행사에 따른 자기주식 교부  시장을 통한 매도(주)
# 1                            자기주식을 교환대상으로 하는 사모 교환사채 발행  시장을 통한 매도(주)
# 2                                              임직원공로금지급  시장을 통한 매도(주)
# 3                                           우리사주조합 무상출연  시장을 통한 매도(주)
# 4     합병시 주주의 주식매수청구권 행사로 취득한 자기주식은 5년 이내에 처분해야 하며, ...  시장을 통한 매도(주)
# ...                                                 ...           ...
# 4163                                                NaN           NaN
# 4164                                                NaN           NaN
# 4165                                                NaN           NaN
# 4166                                                NaN           NaN
# 4167                                                NaN           NaN
#
#       처분예정금액(전체주식)                    누가오래했나         회사명
# 0     1.632000e+07 0 days 00:00:00.000040217       에스티아이
# 1     4.000000e+09           0 days 00:00:00     웨이브일렉트로
# 2     7.200000e+07 0 days 00:00:00.000000008        모베이스
# 3     4.788000e+07           0 days 00:00:00      와이아이케이
# 4     4.561934e+09 0 days 00:00:00.000000007         엔투텍
# ...            ...                       ...         ...
# 4163           NaN                       NaT         JTC
# 4164           NaN                       NaT         미투젠
# 4165           NaN                       NaT         소마젠
# 4166           NaN                       NaT  프레스티지바이오파마
# 4167           NaN                       NaT       네오이뮨텍
#
# [4168 rows x 11 columns]
