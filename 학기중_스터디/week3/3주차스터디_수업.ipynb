# %% [markdown]
# # 3주차 스터디
#
# Made by 35기 코딩부장 류제현

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Pandas를 사용한 데이터 전처리 (심화)
#
#     실제 데이터 전처리 과정을 함께 따라해 봅시다
#
#
# * 코스닥 상장 기업들의 년도별 전환사채(CB)발행 기록이 담긴 3개의 CSV파일이 있습니다.
# * 데이터셋을 하나로 합치고, 데이터가 완전한지 확인해보겠습니다

# %% [markdown]
#     데이터 불러오기

# %%
# 우선 데이터셋을 불러오겠습니다
df2019 = pd.read_csv("Data/전환사채권발행결정_코스닥_2019-01-01-2019-12-31.csv", index_col=0)
df2020 = pd.read_csv("Data/전환사채권발행결정_코스닥_2020-01-01-2020-12-31.csv", index_col=0)
df2021 = pd.read_csv("Data/전환사채권발행결정_코스닥_2021-01-01-2021-12-31.csv", index_col=0)

# 그런데 만약 년도가 2000년부터 2020년까지인 경우처럼 엄청 많을 경우 이렇게 코드를 복사하기 귀찮지 않을까요?
# (또한 변수를 너무 많이 만든다는 부담도 있습니다)
# -> CSV파일 이름이 유사한데 반복문으로 해결할 수 있지 않을까요?
# 이런 경우에 데이터를 저장하기 위해 딕셔너리 자료구조를 자주 사용합니다
df_dict = {}
for year in range(2019,2022):
    df = pd.read_csv("Data/전환사채권발행결정_코스닥_{}-01-01-{}-12-31.csv".format(year,year),
                      index_col=0)
    df_dict[str(year)] = df

# %%
# key를 통해 값에 접근합니다
df_dict["2020"]
# Out:
#           회사명  기업공시코드         공시일                    종류           총액(원)  \
# 0       연이비앤티   90740  2020-12-29   무기명식 이권부무보증 사모 전환사채  10,000,000,000
# 1       연이비앤티   90740  2020-12-29   무기명식 이권부무보증 사모 전환사채  10,000,000,000
# 2    HLB테라퓨틱스  115450  2020-12-29  무기명식 이권부 무보증 사모 전환사채  45,000,000,000
# 3    HLB테라퓨틱스  115450  2020-12-29  무기명식 이권부 무보증 사모 전환사채  10,000,000,000
# 4        휴림로봇   90710  2020-12-28   무기명식 이권부 담보부 사모전환사채   4,000,000,000
# ..        ...     ...         ...                   ...             ...
# 399   SGA솔루션즈  184230  2020-01-09      무기명식 이권무 사모 전환사채   2,000,000,000
# 400     제넨바이오   72520  2020-01-07   무기명식 이권부무보증 사모 전환사채   7,000,000,000
# 401    에이아이비트   39230  2020-01-06  무기명식 이권부 무보증 사모 전환사채  30,000,000,000
# 402      비엘팜텍   65170  2020-01-03     무기명식 무보증 사모 전환사채    6,500,000,000
# 403      EV수성   84180  2020-01-03  무기명식 이권부 담보부 사모 전환사채   4,500,000,000
#
#              사채만기일 표면이자율(%) 만기이자율(%) 사채발행방법            공시코드
# 0    2024년 04월 09일        0        3     사모  20201229000894
# 1    2024년 04월 02일        0        3     사모  20201229000889
# 2    2026년 02월 05일      0.0      3.0     사모  20201229000674
# 3    2026년 02월 01일      0.0      3.0     사모  20201229000472
# 4    2023년 12월 28일        3        5     사모  20201228000974
# ..             ...      ...      ...    ...             ...
# 399  2023년 01월 13일      3.0      3.0     사모  20200109000465
# 400     2023.01.07        -        3     사모  20200107000385
# 401  2023년 01월 13일      0.0      0.0     사모  20200106000592
# 402  2025년 01월 07일        0        3     사모  20200103000476
# 403  2023년 01월 22일      5.0       11     사모  20200103000395
#
# [404 rows x 10 columns]

# %%
# os 모듈을 사용하는 방법도 있습니다(폴더 하나에 자기가 원하는 파일만 들어가 있으면 편리합니다)
lst = os.listdir("Data")
sample_dict = {}
for file in lst[3:]:
    sample_dict[file] = pd.read_csv("Data/{}".format(file))

sample_dict.keys()
# Out:
# dict_keys(['전환사채권발행결정_코스닥_2019-01-01-2019-12-31.csv', '전환사채권발행결정_코스닥_2020-01-01-2020-12-31.csv', '전환사채권발행결정_코스닥_2021-01-01-2021-12-31.csv'])

# %% [markdown]
#     데이터프레임 합치기

# %%
# 데이터 확인
df2019.head()
# Out:
#      회사명  기업공시코드         공시일                    종류           총액(원)  \
# 0   네오티스   85910  2019-12-27  무기명식 이권부 무보증 사모 전환사채  10,000,000,000
# 1  지나인제약   78650  2019-12-27  무기명식 이권부 무보증 사모 전환사채   8,000,000,000
# 2   화신테크   86250  2019-12-27  무기명식 이권부 무보증 사모 전환사채  20,000,000,000
# 3    테크엘   64520  2019-12-27        무기명 사모 일반 전환사채   5,000,000,000
# 4  티로보틱스  117730  2019-12-26      무기명식 무보증 사모 전환사채  10,000,000,000
#
#            사채만기일 표면이자율(%) 만기이자율(%) 사채발행방법            공시코드
# 0  2025년 01월 03일      0.0      1.0     사모  20191227000693
# 1  2025년 01월 03일      0.0      0.0     사모  20191227000514
# 2  2023년 03월 17일      5.0      5.0     사모  20191227000010
# 3  2024년 12월 26일      2.0      2.0     사모  20191227000006
# 4  2022년 12월 27일      0.0      0.0     사모  20191226000394

# %%
# 2019,2020,2021데이터셋을 하나로 합칩시다!
all_df = pd.concat([df2021,df2020,df2019])

# 합친 후, 공시일 순으로 정렬해 봅시다
all_df = all_df.sort_values(by="공시일") \
               .reset_index(drop=True)
all_df
# Out:
#            회사명  기업공시코드         공시일                    종류           총액(원)  \
# 0        대창솔루션   96350  2019-01-03       무기명식 담보부 사모전환사채  35,000,000,000
# 1     리더스 기술투자   19570  2019-01-04  무기명식 이권부 무보증 사모 전환사채  10,000,000,000
# 2     리더스 기술투자   19570  2019-01-04  무기명식 이권부 무보증 사모 전환사채   5,000,000,000
# 3         엔에스엔   31860  2019-01-04  무기명식 무보증 이권부 사모 전환사채   3,000,000,000
# 4         장원테크  174880  2019-01-04  무기명식 이권부 무보증 사모 전환사채  20,000,000,000
# ...        ...     ...         ...                   ...             ...
# 1368     이원컴포텍   88290  2021-12-21  무기명식 이권부 무보증 사모 전환사채  15,000,000,000
# 1369      옵트론텍   82210  2021-12-24  무기명식 이권부 무보증 사모 전환사채   1,600,000,000
# 1370       노터스  278650  2021-12-27  무기명식 이권부 무보증 사모 전환사채  54,600,000,000
# 1371       노터스  278650  2021-12-27  무기명식 이권부 무보증 사모 전환사채  40,000,000,000
# 1372      아이톡시   52770  2021-12-30     무기명식 이권부 무보증 전환사채   1,500,000,000
#
#               사채만기일 표면이자율(%) 만기이자율(%) 사채발행방법            공시코드
# 0     2022년 03월 31일      0.0      4.5     사모  20190103000744
# 1     2022년 02월 25일        0        3     사모  20190104000909
# 2     2022년 02월 25일        0        3     사모  20190104000906
# 3     2022년 01월 18일        3        5     사모  20190104000863
# 4     2022년 02월 27일      2.0      2.0     사모  20190104000871
# ...             ...      ...      ...    ...             ...
# 1368  2025년 01월 25일        2        5     사모  20211221000754
# 1369  2024년 12월 30일     0.00     0.00     사모  20211224000603
# 1370  2025년 01월 13일      0.0      1.0     사모  20211227000668
# 1371  2025년 01월 13일      0.0      1.0     사모  20211227000669
# 1372  2051년 12월 31일      3.0      7.0     사모  20211230000994
#
# [1373 rows x 10 columns]

# %% [markdown]
#     본격적인 데이터 분석에 앞서, 데이터에 이상한 값이 들어있는지 확인해봐야 합니다
#
# 이 데이터는 제가 코드를 짜서 기업공시사이트(KIND)에서 크롤링해 왔습니다. 따라서, 어떤 방식으로 데이터를 수집했는지 지식이 있습니다
#
# 데이터셋의 ["회사명","기업공시코드","공시일"] 컬럼에는 이상한 데이터가 들어있을 확률이 0%입니다.
#
# 따라서, 저에게 필요한 정보인 "총액(원)", "표면이자율(%)","만기이자율(%)"에 이상한 값이 있는지 살펴보겠습니다

# %%
# 우선 "총액(원)" 컬럼을 살펴보겠습니다
## 만약에 이 컬럼에 이상한 값 (숫자가 아닌 문자, 소수 등)이 들어있다면 이 데이터 타입이 int형으로 안바뀌지 않을까요?
## -> 이 아이디어에 착안해서 총액(원)의 데이터타입을 int로 변환해 보겠습니다

# 숫자 중간에 쉼표가 있기 때문에 우선 제거해 줍니다
all_df["총액(원)"] = all_df["총액(원)"].str.replace(",","")

# 이제 int형으로 변형해줍니다
all_df["총액(원)"] = all_df["총액(원)"].astype("int64")
# 오 잘 바뀌네요! 그러면 여기엔 문자는 없고, 정수값만 있다는 뜻 입니다 (문자가 포함되어 있으면 에러메시지가 뜹니다. 궁금하면 직접확인!)

# %%
# 그러면 이제 총액(원)에 0원, 10원 등과 같은 말도 안되는 숫자가 있는 지 확인해 보겠습니다
all_df.loc[all_df["총액(원)"] <= 1000]
# 최소 4억 이상이네요! 충분이 납득이 가는 숫자입니다! 총액 컬럼 확인을 이제 마치겠습니다
# Out:
# Empty DataFrame
# Columns: [회사명, 기업공시코드, 공시일, 종류, 총액(원), 사채만기일, 표면이자율(%), 만기이자율(%), 사채발행방법, 공시코드]
# Index: []

# %%
# 다음으로 표면이자울(%)를 확인해보겠습니다
## 소수로 표시되기 때문에, 우선 float로 변환해보겠습니다
all_df["표면이자율(%)"] = all_df["표면이자율(%)"].astype("float64")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4060\2668757301.py in <module>
#       1 # 다음으로 표면이자울(%)를 확인해보겠습니다
#       2 ## 소수로 표시되기 때문에, 우선 float로 변환해보겠습니다
# ----> 3 all_df["표면이자율(%)"] = all_df["표면이자율(%)"].astype("float64")
#
# c:\Users\user\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# c:\Users\user\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     446
#     447     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     449
#     450     def convert(
#
# c:\Users\user\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     350                     applied = b.apply(f, **kwargs)
#     351                 else:
# --> 352                     applied = getattr(b, f)(**kwargs)
#     353             except (TypeError, NotImplementedError):
#     354                 if not ignore_failures:
#
# c:\Users\user\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     524         values = self.values
#     525
# --> 526         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     527
#     528         new_values = maybe_coerce_values(new_values)
#
# c:\Users\user\anaconda3\lib\site-packages\pandas\core\dtypes\astype.py in astype_array_safe(values, dtype, copy, errors)
#     297
#     298     try:
# --> 299         new_values = astype_array(values, dtype, copy=copy)
#     300     except (ValueError, TypeError):
#     301         # e.g. astype_nansafe can fail on object-dtype of strings
#
# c:\Users\user\anaconda3\lib\site-packages\pandas\core\dtypes\astype.py in astype_array(values, dtype, copy)
#     228
#     229     else:
# --> 230         values = astype_nansafe(values, dtype, copy=copy)
#     231
#     232     # in pandas we don't store numpy str dtypes, so convert to object
#
# c:\Users\user\anaconda3\lib\site-packages\pandas\core\dtypes\astype.py in astype_nansafe(arr, dtype, copy, skipna)
#     168     if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169         # Explicit copy, or required since NumPy can't view from / to object.
# --> 170         return arr.astype(dtype, copy=True)
#     171
#     172     return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '-'

# %%
# 이런 오류가 떴네요! "could not convert string to float: '-'" string값이 있다는 뜻이네요.. 한번 살펴볼까요?
all_df.loc[all_df["표면이자율(%)"] == "-"]
# Out:
#              회사명  기업공시코드         공시일                        종류        총액(원)  \
# 6           옵트론텍   82210  2019-01-07      무기명식 이권부 무보증 사모 전환사채   5000000000
# 52          데코앤이   17680  2019-02-14          무기명식 무보증 사모 전환사채    850000000
# 64        이엠네트웍스   87730  2019-02-22       무기명식 이권부무보증 사모 전환사채   2000000000
# 213         에스와이  109610  2019-05-31  무기명식 이권부 무보증 무담보 사모 전환사채   5000000000
# 306         셀루메드   49180  2019-08-06      무기명식 이권부 무보증 사모 전환사채   6325000500
# 312           퓨전  195440  2019-08-14      무기명식 이권부 무보증 사모 전환사채   2500000000
# 371       버킷스튜디오   66410  2019-10-02          무기명식 무보증 사모 전환사채   5000000000
# 435       명성티엔에스  257370  2019-12-06      무기명식 이권부 무보증 사모 전환사채   5000000000
# 463        제넨바이오   72520  2020-01-07       무기명식 이권부무보증 사모 전환사채   7000000000
# 491          아리온   58220  2020-02-21      무기명식 이권부 무보증 사모 전환사채   3499000000
# 497          아리온   58220  2020-02-26      무기명식 이권부 무보증 사모 전환사채   3600000000
# 551         하이소닉  106080  2020-04-07      무기명식 이권부 무보증 사모 전환사채   2000000000
# 573         하이소닉  106080  2020-04-22      무기명식 이권부 무보증 사모 전환사채   3000000000
# 581         삼영엠텍   54540  2020-04-24      무기명식 이권부 무보증 사모 전환사채   5000000000
# 588     와이제이엠게임즈  193250  2020-05-06          무기명식 무보증 사모 전환사채   2200000000
# 599         네온테크  306620  2020-05-08          무기명식이권부무보증사모전환사채   5000000000
# 617     와이제이엠게임즈  193250  2020-05-20          무기명식 무보증 사모 전환사채   2000000000
# 641        그린플러스  186230  2020-06-15           기명식 무보증 사모 전환사채  10000000000
# 649         네온테크  306620  2020-06-19          무기명식이권부무보증사모전환사채   3000000000
# 736       상아프론테크   89980  2020-09-24  무기명식 이권부 무보증 무담보 사모 전환사채  20000000000
# 738       상아프론테크   89980  2020-09-24  무기명식 이권부 무보증 무담보 사모 전환사채  10000000000
# 746        지어소프트   51160  2020-09-29          무기명식 무보증 사모 전환사채  10000000000
# 777         EV수성   84180  2020-10-29          무기명식 무보증 공모 전환사채    999990000
# 850   스카이문스테크놀로지   33790  2020-12-23      무기명식 이권부 무보증 사모 전환사채   1300000000
# 1174    와이제이엠게임즈  193250  2021-08-11          무기명식 무보증 사모 전환사채   7500000000
# 1251       씨엔플러스  115530  2021-10-29    무기명식 이권부 부모증 사모 영구전환사채   1500000000
#
#               사채만기일 표면이자율(%) 만기이자율(%) 사채발행방법            공시코드
# 6     2024년 01월 09일        -        -     사모  20190107000666
# 52    2022년 02월 14일        -        3     사모  20190214000757
# 64    2022년 02월 22일        -        5     사모  20190222000001
# 213   2024년 06월 04일        -        -     사모  20190531000634
# 306   2022년 08월 07일        -        3     사모  20190806000612
# 312      2022.08.14        -      4.0     사모  20190814002879
# 371   2022년 10월 11일        -      3.0     사모  20191002000478
# 435      2023.02.19        -        2     사모  20191206000337
# 463      2023.01.07        -        3     사모  20200107000385
# 491   2023년 02월 21일        -        -     사모  20200221000683
# 497   2023년 02월 26일        -        -     사모  20200226000756
# 551   2023년 04월 07일        -      2.0     사모  20200407000602
# 573   2023년 04월 22일        -      2.0     사모  20200422000336
# 581   2023년 04월 29일        -      2.0     사모  20200424000703
# 588   2025년 05월 21일        -      2.5     사모  20200506000676
# 599   2023년 05월 13일        -        3     사모  20200508000673
# 617   2025년 05월 28일        -      2.5     사모  20200520000486
# 641   2025년 06월 22일        -        -     사모  20200615000229
# 649   2023년 06월 22일        -        3     사모  20200619000471
# 736   2025년 09월 28일        -        -     사모  20200924000162
# 738   2023년 05월 28일        -        -     사모  20200924000160
# 746      2025.10.08        -        -     사모  20200929000488
# 777   2021년 11월 16일        -        -     공모  20201029000633
# 850   2022년 12월 23일        -        4     사모  20201223000448
# 1174  2026년 08월 18일        -        -     사모  20210811000415
# 1251     2051.10.31        -        -     사모  20211029000863

# %%
# 데이터분석 진행을 위해서 '-'값에 0을 넣어주겠습니다
# 실제 분석 과정에서는 직접 사이트에 들어가 공시 값들을 확인해야 합니다
all_df["표면이자율(%)"] = all_df["표면이자율(%)"].str.replace("-","0")
all_df["만기이자율(%)"] = all_df["만기이자율(%)"].str.replace("-","0")

# %%
# 다시 float로 변환해볼까요?
all_df["표면이자율(%)"] = all_df["표면이자율(%)"].astype("float64")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4060\2090276348.py in <module>
#       1 # 다시 float로 변환해볼까요?
# ----> 2 all_df["표면이자율(%)"] = all_df["표면이자율(%)"].astype("float64")
#
# c:\Users\user\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# c:\Users\user\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     446
#     447     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     449
#     450     def convert(
#
# c:\Users\user\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     350                     applied = b.apply(f, **kwargs)
#     351                 else:
# --> 352                     applied = getattr(b, f)(**kwargs)
#     353             except (TypeError, NotImplementedError):
#     354                 if not ignore_failures:
#
# c:\Users\user\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     524         values = self.values
#     525
# --> 526         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     527
#     528         new_values = maybe_coerce_values(new_values)
#
# c:\Users\user\anaconda3\lib\site-packages\pandas\core\dtypes\astype.py in astype_array_safe(values, dtype, copy, errors)
#     297
#     298     try:
# --> 299         new_values = astype_array(values, dtype, copy=copy)
#     300     except (ValueError, TypeError):
#     301         # e.g. astype_nansafe can fail on object-dtype of strings
#
# c:\Users\user\anaconda3\lib\site-packages\pandas\core\dtypes\astype.py in astype_array(values, dtype, copy)
#     228
#     229     else:
# --> 230         values = astype_nansafe(values, dtype, copy=copy)
#     231
#     232     # in pandas we don't store numpy str dtypes, so convert to object
#
# c:\Users\user\anaconda3\lib\site-packages\pandas\core\dtypes\astype.py in astype_nansafe(arr, dtype, copy, skipna)
#     168     if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169         # Explicit copy, or required since NumPy can't view from / to object.
# --> 170         return arr.astype(dtype, copy=True)
#     171
#     172     return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '0.0, '

# %%
# 이런... 0.0, 라는 값이 있어서 (쉼표때문에) 변환이 안되는 군요... 쉼표를 제거합시다
all_df["표면이자율(%)"] = all_df["표면이자율(%)"].str.replace("," , "")

# %%
# 다시 float로 변환해 봅시다
all_df["표면이자율(%)"] = all_df["표면이자율(%)"].astype("float64")
# 드디어 성공했습니다!!

# %%
# 길고긴 전처리가 끝났습니다!!
all_df
# Out:
#            회사명  기업공시코드         공시일                    종류        총액(원)  \
# 0        대창솔루션   96350  2019-01-03       무기명식 담보부 사모전환사채  35000000000
# 1     리더스 기술투자   19570  2019-01-04  무기명식 이권부 무보증 사모 전환사채  10000000000
# 2     리더스 기술투자   19570  2019-01-04  무기명식 이권부 무보증 사모 전환사채   5000000000
# 3         엔에스엔   31860  2019-01-04  무기명식 무보증 이권부 사모 전환사채   3000000000
# 4         장원테크  174880  2019-01-04  무기명식 이권부 무보증 사모 전환사채  20000000000
# ...        ...     ...         ...                   ...          ...
# 1368     이원컴포텍   88290  2021-12-21  무기명식 이권부 무보증 사모 전환사채  15000000000
# 1369      옵트론텍   82210  2021-12-24  무기명식 이권부 무보증 사모 전환사채   1600000000
# 1370       노터스  278650  2021-12-27  무기명식 이권부 무보증 사모 전환사채  54600000000
# 1371       노터스  278650  2021-12-27  무기명식 이권부 무보증 사모 전환사채  40000000000
# 1372      아이톡시   52770  2021-12-30     무기명식 이권부 무보증 전환사채   1500000000
#
#               사채만기일  표면이자율(%) 만기이자율(%) 사채발행방법            공시코드
# 0     2022년 03월 31일       0.0      4.5     사모  20190103000744
# 1     2022년 02월 25일       0.0        3     사모  20190104000909
# 2     2022년 02월 25일       0.0        3     사모  20190104000906
# 3     2022년 01월 18일       3.0        5     사모  20190104000863
# 4     2022년 02월 27일       2.0      2.0     사모  20190104000871
# ...             ...       ...      ...    ...             ...
# 1368  2025년 01월 25일       2.0        5     사모  20211221000754
# 1369  2024년 12월 30일       0.0     0.00     사모  20211224000603
# 1370  2025년 01월 13일       0.0      1.0     사모  20211227000668
# 1371  2025년 01월 13일       0.0      1.0     사모  20211227000669
# 1372  2051년 12월 31일       3.0      7.0     사모  20211230000994
#
# [1373 rows x 10 columns]

# %%
# 무슨 종류가 있는지 확인해봅시다
all_df["종류"].unique()  # 너무 많다!(전처리 필요)

# 공백을 전부 제거해 보겠습니다
all_df["종류"].apply(lambda x: x.replace(" ","")) \
              .apply(lambda x: x.replace("\xa0", "")).unique() # 종류가 굉장히 많군요
# Out:
# array(['무기명식담보부사모전환사채', '무기명식이권부무보증사모전환사채', '무기명식무보증이권부사모전환사채',
#        '무기명식무보증사모전환사채', '무기명식사모전환사채', '무기명식무이권부무보증사모전환사채',
#        '기명식무보증무담보사모전환사채', '기명식이권부무보증사모전환사채', '무기명무보증사모전환사채',
#        '무기명식무보증국내사모전환사채', '기명식무보증사모전환사채', '국내무기명식이권부무보증사모전환사채',
#        '무보증사모전환사채', '무기명식무보증담보부사모전환사채', '무기명식무보증무담보사모전환사채',
#        '기명식무이권부무보증사모전환사채', '무기명식이권부무보증무담보사모전환사채', '무기명식이권부무보증전환사채',
#        '무기명식무보증사모사채', '무기명식이권부무보증공모전환사채', '무기명무보증무담보', '무기명이권부무보증사모전환사채',
#        '무기명식이권부무보증사모담보부전환사채발행의건', '국내무기명식무보증사모전환사채',
#        '무기명식무이권부무보증무담보사모전환사채', '무기명식이권부무보증사모담보부전환사채', '무기명식이권부사모전환사채',
#        '후순위무기명식무보증사모전환사채(신종자본증권)', '무기명식이권부무보증후순위사모전환사채',
#        '무기명식이원부무보증사모전환사채', '제1회무기명식이권부무보증무담보사모전환사채', '무기명사모일반전환사채',
#        '무기명식이권부담보부사모전환사채', '무기명식이권무사모전환사채', '무기명식이권부무보증담보부사모전환사채',
#        '기가레인무기명식사모전환사채', '무기명식무보증전환사채', '무기명식이권부담보권사모전환사채',
#        '기명식이권부담보부사모전환사채', '무기명이권부.무보증사모전환사채', '전환사채', '해외무기명식무보증사모전환사채',
#        '무기명식무보증이권부전환사채', '국내무기명식무보증담보부사모전환사채', '국내무보증사모전환사채',
#        '제14회차무기명이권부무담보무보증사모전환사채', '국내무기명식이권부무보증사모전환사채,',
#        '무기명식무보증이권부사모전환사채(담보有)', '무기명식무보증공모전환사채', '기명식무이권부사모전환사채',
#        '무기명식무이권부무보증사모전환사채,', '무기명무보증전환사채', '무기명식이권부담보부전환사채',
#        '국내기명식이권부무보증사모전환사채', '해외기명식무보증사모전환사채', '무기명식이권무무보증사모전환사채',
#        '기명식사모전환사채', '무기명식이권부무보증사모전환사채,', '제8회무기명식이권부무보증사모전환사채',
#        '무기명식이권부사모선순위전환사채', '무기명식이권부사모후순위전환사채', '제6회무기명식이권부무보증사모전환사채',
#        '무기명식이권부부모증사모영구전환사채', '무기명식이권부무보증후순위전환사채', '무기명식이권무보증사모전환사채'],
#       dtype=object)

# %%
# 각 종류별로 발행 횟수를 count 해봅시다
all_df["종류"] = all_df["종류"].apply(lambda x: x.replace(" ","")) \
                              .apply(lambda x: x.replace("\xa0", ""))

# 무기명식 이권부 무보증 사모 전환사채 발행이 가장 흔하군요
all_df["종류"].value_counts()
# Out:
# 무기명식이권부무보증사모전환사채            829
# 무기명식무보증사모전환사채               258
# 무기명식무보증이권부사모전환사채             28
# 무기명식이권부사모전환사채                23
# 국내무기명식이권부무보증사모전환사채           17
#                            ...
# 제1회무기명식이권부무보증무담보사모전환사채        1
# 무기명식이원부무보증사모전환사채              1
# 무기명식이권부무보증후순위사모전환사채           1
# 후순위무기명식무보증사모전환사채(신종자본증권)      1
# 무기명식이권무보증사모전환사채               1
# Name: 종류, Length: 65, dtype: int64

# %%
# 평균 사채 발행 총액
all_df["총액(원)"].mean(), all_df["총액(원)"].std()
# Out:
# (14068887436.79534, 23557456381.70608)

# %%
# 발행 기간(공시일)별로 금리의 변화를 살펴보는 것도 재미있을 것 같습니다

# 날짜 데이터를 다룰 때는 항상 datetime으로 변환하면 편합니다
all_df["공시일"] = pd.to_datetime(all_df["공시일"])

# 문자형에 str을 붙여주는 것처럼 datetime에는 dt를 붙여서 접근 할 수 있다
## 데이터프레임에 년(year) 정보를 추가
all_df["년"] = all_df["공시일"].dt.year

# %%
all_df
# Out:
#            회사명  기업공시코드        공시일                종류        총액(원)  \
# 0        대창솔루션   96350 2019-01-03     무기명식담보부사모전환사채  35000000000
# 1     리더스 기술투자   19570 2019-01-04  무기명식이권부무보증사모전환사채  10000000000
# 2     리더스 기술투자   19570 2019-01-04  무기명식이권부무보증사모전환사채   5000000000
# 3         엔에스엔   31860 2019-01-04  무기명식무보증이권부사모전환사채   3000000000
# 4         장원테크  174880 2019-01-04  무기명식이권부무보증사모전환사채  20000000000
# ...        ...     ...        ...               ...          ...
# 1368     이원컴포텍   88290 2021-12-21  무기명식이권부무보증사모전환사채  15000000000
# 1369      옵트론텍   82210 2021-12-24  무기명식이권부무보증사모전환사채   1600000000
# 1370       노터스  278650 2021-12-27  무기명식이권부무보증사모전환사채  54600000000
# 1371       노터스  278650 2021-12-27  무기명식이권부무보증사모전환사채  40000000000
# 1372      아이톡시   52770 2021-12-30    무기명식이권부무보증전환사채   1500000000
#
#               사채만기일  표면이자율(%) 만기이자율(%) 사채발행방법            공시코드     년
# 0     2022년 03월 31일       0.0      4.5     사모  20190103000744  2019
# 1     2022년 02월 25일       0.0        3     사모  20190104000909  2019
# 2     2022년 02월 25일       0.0        3     사모  20190104000906  2019
# 3     2022년 01월 18일       3.0        5     사모  20190104000863  2019
# 4     2022년 02월 27일       2.0      2.0     사모  20190104000871  2019
# ...             ...       ...      ...    ...             ...   ...
# 1368  2025년 01월 25일       2.0        5     사모  20211221000754  2021
# 1369  2024년 12월 30일       0.0     0.00     사모  20211224000603  2021
# 1370  2025년 01월 13일       0.0      1.0     사모  20211227000668  2021
# 1371  2025년 01월 13일       0.0      1.0     사모  20211227000669  2021
# 1372  2051년 12월 31일       3.0      7.0     사모  20211230000994  2021
#
# [1373 rows x 11 columns]

# %%
# 년도별로 묶어(groupby)보자
gb = all_df[["총액(원)","표면이자율(%)","년"]].groupby("년").mean()
gb
# 채권발행 금리가 낮아지면서, 발행량도 증가하는 것을 볼 수 있습니다
# Out:
#              총액(원)  표면이자율(%)
# 년
# 2019  1.104964e+10  1.554348
# 2020  1.179812e+10  1.281089
# 2021  1.859982e+10  0.946130

# %% [markdown]
# ## 2. Pandas 보충
#
#     각 데이터별로 하나라도 NaN값이 있는 팽귄을 찾아봅시다

# %%
from seaborn import load_dataset

df = load_dataset('penguins')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %%
# 결측치(NaN) 값을 찾아보자 -> nan은 연산자가 먹히지 않는다
#df == np.nan -> 작동하지 않음

df.isna()
# Out:
#      species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      False   False           False          False              False
# 1      False   False           False          False              False
# 2      False   False           False          False              False
# 3      False   False            True           True               True
# 4      False   False           False          False              False
# ..       ...     ...             ...            ...                ...
# 339    False   False            True           True               True
# 340    False   False           False          False              False
# 341    False   False           False          False              False
# 342    False   False           False          False              False
# 343    False   False           False          False              False
#
#      body_mass_g    sex
# 0          False  False
# 1          False  False
# 2          False  False
# 3           True   True
# 4          False  False
# ..           ...    ...
# 339         True   True
# 340        False  False
# 341        False  False
# 342        False  False
# 343        False  False
#
# [344 rows x 7 columns]

# %%
# True는 1, False는 0인 성질을 사용

idx = df.isna().sum(axis=1) >=1 
# 이걸 인덱스로 주면 되겠다!!

# %%
df[idx]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# 47   Adelie      Dream            37.5           18.9              179.0
# 246  Gentoo     Biscoe            44.5           14.3              216.0
# 286  Gentoo     Biscoe            46.2           14.4              214.0
# 324  Gentoo     Biscoe            47.3           13.8              216.0
# 336  Gentoo     Biscoe            44.5           15.7              217.0
# 339  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g  sex
# 3            NaN  NaN
# 8         3475.0  NaN
# 9         4250.0  NaN
# 10        3300.0  NaN
# 11        3700.0  NaN
# 47        2975.0  NaN
# 246       4100.0  NaN
# 286       4650.0  NaN
# 324       4725.0  NaN
# 336       4875.0  NaN
# 339          NaN  NaN

# %%
# isin을 사용해도 된다
df.isin([np.nan]).any(1)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4060\510589721.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.any and Series.any will be keyword-only.
#   df.isin([np.nan]).any(1)
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 339     True
# 340    False
# 341    False
# 342    False
# 343    False
# Length: 344, dtype: bool
