# %%
import numpy as npa
import pandas as pd
import matplotlib.pyplot as plt

# %%
stock = pd.read_csv("Data/Stock.csv", index_col=0, parse_dates=True)
market = pd.read_csv("Data/kospi.csv",index_col=0, parse_dates=True)

# %%
pct = stock.pct_change()

# %%
pct
# Out:
#                  HMM   Samsung     S-Oil    NCsoft   Hyundai
# Date
# 2018-01-02       NaN       NaN       NaN       NaN       NaN
# 2018-01-03 -0.043912  0.011760 -0.029915 -0.025756  0.006689
# 2018-01-04 -0.034447 -0.010461  0.000000 -0.028736 -0.026578
# 2018-01-05  0.002162  0.020360 -0.004405 -0.001183  0.017065
# 2018-01-08 -0.024811 -0.001919 -0.013274 -0.004739  0.013423
# ...              ...       ...       ...       ...       ...
# 2022-12-23 -0.033408 -0.016920 -0.002268 -0.020525 -0.009464
# 2022-12-26  0.002304 -0.003442  0.017045  0.005821  0.006369
# 2022-12-27  0.004598  0.003454 -0.004469  0.000000  0.000000
# 2022-12-28 -0.080092 -0.025818 -0.031425  0.003472 -0.025316
# 2022-12-29 -0.027363 -0.022968 -0.033604  0.033449 -0.019481
#
# [1232 rows x 5 columns]

# %%
# equal weight 전략의 수익율
strat_rtn = pct.mean(1)

# %%
strat_rtn
# Out:
# Date
# 2018-01-02         NaN
# 2018-01-03   -0.016227
# 2018-01-04   -0.020044
# 2018-01-05    0.006800
# 2018-01-08   -0.006264
#                 ...
# 2022-12-23   -0.016517
# 2022-12-26    0.005619
# 2022-12-27    0.000717
# 2022-12-28   -0.031836
# 2022-12-29   -0.013993
# Length: 1232, dtype: float64

# %%
(strat_rtn +1).cumprod().plot(figsize=(24,12));
